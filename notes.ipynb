# %%
import pandas as pd

df = pd.read_csv("data/ohe_acled.csv")
df.head()
# Out:
#    Unnamed: 0 event_id_cnty  event_date  year  time_precision  \
# 0           0      BFO12795  2024-11-08  2024               1
# 1           1      BFO12802  2024-11-08  2024               1
# 2           2      BFO12804  2024-11-08  2024               1
# 3           3       BOL6732  2024-11-08  2024               1
# 4           4       BOL6733  2024-11-08  2024               1
#
#             disorder_type                  event_type  \
# 0      Political violence  Violence against civilians
# 1  Strategic developments      Strategic developments
# 2      Political violence                     Battles
# 3      Political violence                       Riots
# 4          Demonstrations                    Protests
#
#                                          actor1  \
# 0  JNIM: Group for Support of Islam and Muslims
# 1  JNIM: Group for Support of Islam and Muslims
# 2  JNIM: Group for Support of Islam and Muslims
# 3                             Rioters (Bolivia)
# ...

# %%
df.notes
# Out:
# 0          On 8 November 2024, JNIM militants attacked th...
# 1          Other: On 8 November 2024, JNIM militants cond...
# 2          On 8 November 2024, JNIM militants attacked a ...
# 3          On 8 November 2024, in La Paz (La Paz), a grou...
# 4          On 8 November 2024, in La Paz (La Paz), a grou...
#                                  ...
# 2342131    Around 1 January 1997 (month of), Military For...
# 2342132    Around 1 January 1997 (month of), Kamajor Mili...
# 2342133    The total number of chiefs in the past 6 month...
# 2342134                                                 base
# 2342135    4 deaths reported, denied by both sides, anti-...
# Name: notes, Length: 2342136, dtype: object
